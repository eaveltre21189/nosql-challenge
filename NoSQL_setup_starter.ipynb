# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Part 1: Database and Jupyter Notebook Set Up

# %% [markdown]
# Import the data provided in the `establishments.json` file from your Terminal. Name the database `uk_food` and the collection `establishments`.
#
# Within this markdown cell, copy the line of text you used to import the data from your Terminal. This way, future analysts will be able to repeat your process.
#
# e.g.: Import the dataset with `YOUR IMPORT TEXT HERE`

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# confirm that our new database was created
print(mongo.list_database_names())
# Out:
# ['admin', 'config', 'local', 'uk_food']

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our new database
print(db.list_collection_names())
# Out:
# ['establishments']

# %%
# review a document in the establishments collection
pprint(db.establishments.find_one())
# Out:
# {'AddressLine1': 'The Bay',
#  'AddressLine2': 'St Margarets Bay',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'Refreshment Kiosk',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4587.347174863443,
#  'FHRSID': 254719,
#  'LocalAuthorityBusinessID': 'PI/000069980',
#  'LocalAuthorityCode': '182',
#  'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#  'LocalAuthorityName': 'Dover',
#  'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT15 6DY',
#  'RatingDate': '2022-03-24T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': '5',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64615406dc83a4673af21184'),
#  'geocode': {'latitude': '51.152225', 'longitude': '1.387974'},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/254719',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 5}}

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 2: Update the Database

# %% [markdown]
# 1. An exciting new halal restaurant just opened in Greenwich, but hasn't been rated yet. The magazine has asked you to include it in your analysis. Add the following restaurant "Penang Flavours" to the database.

# %%
# Create a dictionary for the new restaurant data
Penang_Flavours = {
    "BusinessName":"Penang Flavours",
    "BusinessType":"Restaurant/Cafe/Canteen",
    "BusinessTypeID":"",
    "AddressLine1":"Penang Flavours",
    "AddressLine2":"146A Plumstead Rd",
    "AddressLine3":"London",
    "AddressLine4":"",
    "PostCode":"SE18 7DY",
    "Phone":"",
    "LocalAuthorityCode":"511",
    "LocalAuthorityName":"Greenwich",
    "LocalAuthorityWebSite":"http://www.royalgreenwich.gov.uk",
    "LocalAuthorityEmailAddress":"health@royalgreenwich.gov.uk",
    "scores":{
        "Hygiene":"",
        "Structural":"",
        "ConfidenceInManagement":""
    },
    "SchemeType":"FHRS",
    "geocode":{
        "longitude":"0.08384000",
        "latitude":"51.49014200"
    },
    "RightToReply":"",
    "Distance":4623.9723280747176,
    "NewRatingPending":True
}

# %%
# Insert the new restaurant into the collection
establishments.insert_one(Penang_Flavours)

# %%
# Check that the new restaurant was inserted
results = establishments.find({'BusinessName': 'Penang Flavours'})
for result in results:
    pprint(result)
# Out:
# {'AddressLine1': 'Penang Flavours',
#  'AddressLine2': '146A Plumstead Rd',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '',
#  'Distance': 4623.972328074718,
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': True,
#  'Phone': '',
#  'PostCode': 'SE18 7DY',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64615636681308f66b921f55'),
#  'geocode': {'latitude': '51.49014200', 'longitude': '0.08384000'},
#  'scores': {'ConfidenceInManagement': '', 'Hygiene': '', 'Structural': ''}}

# %% [markdown]
# 2. Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the `BusinessTypeID` and `BusinessType` fields.

# %%
# Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the BusinessTypeID and BusinessType fields
query = {'BusinessType': 'Restaurant/Cafe/Canteen'}
fields = {'BusinessType': 1, 'BusinessTypeID': 1}

# Capture the results to a variable
results = list(establishments.find(query, fields))

# Pretty print the results
for result in results:
    pprint(result)
# Out:
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21184')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21186')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21187')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21188')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af2118a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af2118c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af2118d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21190')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21193')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21196')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21197')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21199')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af211a2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af211a6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af211aa')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af211b4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af211b6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af211b7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af211ba')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af211bd')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af211be')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af211c0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af211c3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af211c4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af211c6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af211c7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af211c8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af211cd')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af211cf')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af211d1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af211d5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af211d9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af211da')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af211dc')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af211dd')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af211de')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af211e7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af211ea')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af211f1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af211f2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af211f3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af211f6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af211f8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af211f9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af211fb')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21205')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21207')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af2120a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af2120e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af2120f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21210')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21211')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21213')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af2121a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21220')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21221')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21225')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21229')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21230')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21231')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21233')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21234')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21235')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af2123f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21241')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21244')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af2124a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af2124c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af2124f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21250')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21255')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af2125a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af2125d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21261')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21270')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21272')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21273')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21274')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21280')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21283')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21284')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21286')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21288')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21294')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21297')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af2129c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af212a2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af212a4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af212a7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af212ae')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af212b0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af212ba')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af212bd')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af212bf')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af212c0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af212c2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af212c6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af212ca')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af212cc')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af212ce')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af212cf')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af212d1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af212d2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af212d3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af212d4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af212d6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af212d8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af212da')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af212dc')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af212df')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af212e1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af212eb')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af212ef')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af212f2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af212f3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af212f6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af212fd')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af212ff')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21302')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21303')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21304')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21305')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21309')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af2130d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af2130f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21310')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af2131d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af2131f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21320')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21324')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21326')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af2132e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21330')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21331')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21332')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af2133b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af2133c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21347')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af2134a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af2134b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af2134f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21351')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21356')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af2135f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21360')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21366')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21372')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af2137c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af2139c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af213a4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af213a7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af213aa')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af213ae')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af213b2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af213ce')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af213d0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af213ea')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af213ec')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af213f9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af213fa')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af213fc')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af213ff')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af2140e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af2141a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af2141b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21425')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21428')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af2142a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af2142b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af2142f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21430')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21435')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21438')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21439')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af2143e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21448')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21449')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af2144c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21459')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af2145e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af2145f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21464')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21474')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21477')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af2147d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af2147e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af2147f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af2148d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21491')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21496')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21498')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af2149a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af2149d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af214a0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af214af')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af214b6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af214be')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af214c2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af214c4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af214c5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af214c6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af214ca')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af214cb')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af214cd')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af214cf')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af214d4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af214d5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af214d7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af214d9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af214de')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af214e0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af214e1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af214e2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af214e3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af214e8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af214e9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af214f4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af214f5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af214fa')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af214fb')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af214fc')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af214fe')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21502')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21506')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21507')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21509')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af2150a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af2150c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af2150f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21512')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21513')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21518')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21519')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af2151d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af2151f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21525')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21527')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af2152c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21531')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21533')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21536')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af2153c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af2153d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af2153e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21543')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21546')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21549')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af2154b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af2154f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21551')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21552')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21554')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21555')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21556')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21558')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af2155e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21560')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21561')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21562')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af2156e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af2156f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21574')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21575')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21577')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af2157a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af2157e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af2157f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21580')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21581')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21585')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21586')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af2158a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af2158f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21596')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af215a0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af215a1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af215a5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af215b9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af215bc')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af215be')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af215c5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af215c8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af215ce')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af215d0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af215e1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af215e9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af215ec')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af215ee')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af215ef')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af215f5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af215fc')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af215ff')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21600')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21601')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21602')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21603')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21606')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21607')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21608')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21609')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af2160a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af2160b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21613')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af2161f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21621')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21623')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21624')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21625')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21626')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21627')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21628')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21629')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af2162b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af2162e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21631')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21633')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21636')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af2163f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21640')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21641')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21642')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21643')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21644')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21646')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21649')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af2164a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21655')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21657')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21658')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af2165b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af2165c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21664')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21669')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af2166a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af2166b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21670')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21671')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21679')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af2167b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af2167d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21685')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21686')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af2168d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21693')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21697')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af2169a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af2169c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af216a0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af216a3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af216a7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af216ae')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af216b2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af216b3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af216b6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af216b8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af216bc')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af216c0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af216c3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af216c6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af216c7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af216ca')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af216d0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af216d2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af216d7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af216dc')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af216dd')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af216de')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af216df')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af216e0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af216e1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af216e2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af216e3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af216e5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af216e6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af216e9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af216ec')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af216ed')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af216ee')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af216f0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af216f2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af216f3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af216f5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af216f6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af216f8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af216f9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af216fa')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af216fc')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af216fd')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21700')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21701')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af2170a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af2170c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af2170d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af2170f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21710')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21711')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21712')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21719')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af2171a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21721')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21725')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21726')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21727')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af2172b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21730')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21733')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af2173c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21747')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af2174f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21754')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af2175a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af2175b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af2175c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21765')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21769')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21772')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21775')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21776')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21777')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af2177c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af2177f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21784')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21785')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21789')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21791')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af21797')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af2179b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64615406dc83a4673af217a0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
# ...
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2aad2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2aad3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2aad4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2aad5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2aad6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2aad7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2aadf')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2aae0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2aae3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2aae4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2aaea')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2aaf4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2aaf6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2aaf7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2aafb')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2aafc')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2aafd')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2aafe')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2ab00')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2ab01')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2ab05')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2ab06')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2ab08')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2ab09')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2ab0a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2ab0d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2ab0e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2ab10')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2ab11')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2ab12')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2ab14')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2ab1d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2ab1e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2ab1f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2ab20')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2ab21')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2ab22')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2ab25')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2ab29')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2ab2b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2ab34')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2ab36')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2ab37')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2ab42')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2ab43')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2ab45')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2ab4c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2ab4d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2ab4f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2ab57')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2ab7b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2ab82')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2ab87')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2ab89')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2ab8a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2ab8b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2ab90')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2ab91')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2ab94')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2ab95')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2ab98')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2ab9b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2ab9c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2aba8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2abab')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2abba')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2abbc')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2abbf')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2abc0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2abce')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2abcf')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2abd3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2abd4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2abd8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2abda')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2abdb')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2abdc')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2abe5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2abf6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2abfd')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2ac04')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2ac07')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2ac0c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2ac0f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2ac17')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2ac1c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2ac1d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2ac20')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2ac23')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2ac25')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2ac2b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2ac31')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2ac35')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2ac36')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2ac38')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2ac39')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2ac3b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2ac3d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2ac3f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2ac40')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2ac44')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2ac45')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2ac47')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2ac4b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2ac4c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2ac4d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2ac4f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2ac50')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2ac52')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2ac53')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2ac54')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2ac55')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2ac57')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2ac5c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2ac5e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2ac5f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2ac63')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2ac67')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2ac68')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2ac69')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2ac71')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2ac74')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2ac76')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2ac79')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2ac85')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2ac8a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2ac8c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2ac8e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2ac91')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2ac92')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2aca0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2acaf')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2acb2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2acb9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2acc3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2acc5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2acca')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2accc')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2acd0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2acd4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2acda')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6461540bdc83a4673af2ace5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '',
#  '_id': ObjectId('64615636681308f66b921f55')}

# %% [markdown]
# 3. Update the new restaurant with the `BusinessTypeID` you found.

# %%
# Update the new restaurant with the correct BusinessTypeID
establishments.update_one({'BusinessName': 'Penang Flavours'}, {'$set': {'BusinessTypeID': 1}})

# %%
# Confirm that the new restaurant was updated
results = establishments.find({'BusinessName': 'Penang Flavours'})
for result in results:
    pprint(result)
# Out:
# {'AddressLine1': 'Penang Flavours',
#  'AddressLine2': '146A Plumstead Rd',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'Distance': 4623.972328074718,
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': True,
#  'Phone': '',
#  'PostCode': 'SE18 7DY',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64615636681308f66b921f55'),
#  'geocode': {'latitude': '51.49014200', 'longitude': '0.08384000'},
#  'scores': {'ConfidenceInManagement': '', 'Hygiene': '', 'Structural': ''}}

# %% [markdown]
# 4. The magazine is not interested in any establishments in Dover, so check how many documents contain the Dover Local Authority. Then, remove any establishments within the Dover Local Authority from the database, and check the number of documents to ensure they were deleted.

# %%
# Find how many documents have LocalAuthorityName as "Dover"
query = {'LocalAuthorityName': 'Dover'}
results = list(establishments.find(query))
print(len(results))
# Out:
# 994

# %%
# Delete all documents where LocalAuthorityName is "Dover"
establishments.delete_many({'LocalAuthorityName': 'Dover'})

# %%
# Check if any remaining documents include Dover
query = {'LocalAuthorityName': 'Dover'}
results = list(establishments.find(query))
print(len(results))
# Out:
# 0

# %%
# Check that other documents remain with 'find_one'
establishments.find_one()
# Out:
# {'_id': ObjectId('64615406dc83a4673af21469'),
#  'FHRSID': 647177,
#  'ChangesByServerID': 0,
#  'LocalAuthorityBusinessID': 'PI/000041489',
#  'BusinessName': 'Wear Bay Bowls Club',
#  'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  'AddressLine1': 'Wear Bay Road',
#  'AddressLine2': 'Folkestone',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'PostCode': 'CT19 6PY',
#  'Phone': '',
#  'RatingValue': '4',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingDate': '2014-03-31T00:00:00',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 10},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': '1.196408', 'latitude': '51.086058'},
#  'RightToReply': '',
#  'Distance': 4591.821311183521,
#  'NewRatingPending': False,
#  'meta': {'dataSource': None,
#   'extractDate': '0001-01-01T00:00:00',
#   'itemCount': 0,
#   'returncode': None,
#   'totalCount': 0,
#   'totalPages': 0,
#   'pageSize': 0,
#   'pageNumber': 0},
#  'links': [{'rel': 'self',
#    'href': 'https://api.ratings.food.gov.uk/establishments/647177'}]}

# %% [markdown]
# 5. Some of the number values are stored as strings, when they should be stored as numbers.

# %% [markdown]
# Use `update_many` to convert `latitude` and `longitude` to decimal numbers.

# %%
# Change the data type from String to Decimal for longitude and latitude

# %% [markdown]
# Use `update_many` to convert `RatingValue` to integer numbers.

# %%
# Set non 1-5 Rating Values to Null
non_ratings = ["AwaitingInspection", "Awaiting Inspection", "AwaitingPublication", "Pass", "Exempt"]
establishments.update_many({"RatingValue": {"$in": non_ratings}}, [ {'$set':{ "RatingValue" : None}} ])

# %%
# Change the data type from String to Integer for RatingValue

# %%
# Check that the coordinates and rating value are now numbers
